# %%
import numpy as np
import pandas as pd
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import re

class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

excel = pd.read_excel("DBTweets.xlsx")
tweets = excel.AT
txt = tweets[1]
for i in range(1, len(tweets)):
        txt = txt + tweets[i] + " "
txt=txt.lower()

# %%
def contar(str):
    count = dict()
    palabras = str.split()
    for word in palabras:
        if word in count:
            count[word] = count[word] + 1
        else:
            count[word] = 1
    return count
cuentas = contar(txt)

# %%
def repeticiones(dict):
    for keys in dict:
        if dict[keys] == max(dict.values()):
            print('La palabra que más se repite es', color.RED+ keys + color.END,', con un valor de: ', dict[keys])
repeticiones(cuentas)
# Out:
# La palabra que más se repite es de , con un valor de:  1740

# %%
#Para crear el wordcloud
def create_word_cloud(string,int):
   maskArray = np.array(Image.open("mascara.png"))
   cloud = WordCloud(background_color = "white", max_words = 200, mask = maskArray, stopwords = set(STOPWORDS))
   cloud.generate(string)
   cloud.to_file("wordCloud"+str(int)+".png")
create_word_cloud(txt,1)

# %%
#Esta parte del código es para quitar los conectores, que OBVIAMENTE son los que más se van a repetir
#Dando relevancia a palabras más significativas
filtrar = dict()
for keys in cuentas:
    if len(keys)>3:
        filtrar[keys] = cuentas[keys]
repeticiones(filtrar)
def generartxt(dict):
    par = ''
    for keys in filtrar:
        par = par + keys+ ' '
    return par
textofiltrado= generartxt(filtrar)
# Out:
# La palabra que más se repite es para , con un valor de:  306

# %%
#Ahora quitamos las URLs, no nos sirven de mucho (Creo), con algunos valores raritos
def quitar_urls (vTEXT):
    vTEXT = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', vTEXT, flags=re.MULTILINE)
    vTEXT = re.sub(r'\x1a', '', vTEXT, flags=re.MULTILINE)
    return(vTEXT)
sin_URLs = quitar_urls(textofiltrado)
txtfinal = contar(sin_URLs)
repeticiones(txtfinal)
# Out:
# La palabra que más se repite es oposición , con un valor de:  2
# La palabra que más se repite es colombia , con un valor de:  2
# La palabra que más se repite es nuestra , con un valor de:  2
# La palabra que más se repite es calidad , con un valor de:  2
# La palabra que más se repite es entregamos , con un valor de:  2
# La palabra que más se repite es presupuesto , con un valor de:  2
# La palabra que más se repite es urgencias. , con un valor de:  2
# La palabra que más se repite es durante , con un valor de:  2
# La palabra que más se repite es vamos , con un valor de:  2
# La palabra que más se repite es servicios , con un valor de:  2
# La palabra que más se repite es cambiamos , con un valor de:  2
# La palabra que más se repite es mira , con un valor de:  2
# La palabra que más se repite es nosotros , con un valor de:  2
# La palabra que más se repite es vida. , con un valor de:  2
# La palabra que más se repite es ¡gracias! , con un valor de:  2
# La palabra que más se repite es aumento , con un valor de:  2
# La palabra que más se repite es #claudianuestraalcaldesa , con un valor de:  2

# %%
txtfinal = sorted(txtfinal.items(),reverse = True,  key=lambda item: item[1])
txtfinal
# Out:
# [('oposición', 2),
#  ('colombia', 2),
#  ('nuestra', 2),
#  ('calidad', 2),
#  ('entregamos', 2),
#  ('presupuesto', 2),
#  ('urgencias.', 2),
#  ('durante', 2),
#  ('vamos', 2),
#  ('servicios', 2),
#  ('cambiamos', 2),
#  ('mira', 2),
#  ('nosotros', 2),
#  ('vida.', 2),
#  ('¡gracias!', 2),
#  ('aumento', 2),
#  ('#claudianuestraalcaldesa', 2),
#  ('defensa', 1),
#  ('santiago', 1),
#  ('uribe', 1),
#  ('masacre', 1),
#  ('jamundí:', 1),
#  ('recompensa', 1),
#  ('$300', 1),
#  ('millones', 1),
#  ('autores', 1),
#  ('jamundí', 1),
#  ('cali', 1),
#  ('caracol', 1),
#  ('radio', 1),
#  ('reducción', 1),
#  ('gradual', 1),
#  ('aportes', 1),
#  ('salud', 1),
#  ('pensionados', 1),
#  ('vulnerables', 1),
#  ('beneficiará', 1),
#  ('colombianos', 1),
#  ('@colpensiones', 1),
#  ('fondos', 1),
#  ('privados,', 1),
#  ('reciben', 1),
#  ('hasta', 1),
#  ('salarios', 1),
#  ('mínimos', 1),
#  ('representan', 1),
#  ('casi', 1),
#  ('jubilados', 1),
#  ('país.', 1),
#  ('#ahorroparalospensionados', 1),
#  ('pdte', 1),
#  ('@ivanduque', 1),
#  ('socialización', 1),
#  ('cotización', 1),
#  ('para', 1),
#  ('menores', 1),
#  ('ingresos.', 1),
#  ('#leydecrecimientoeconómico', 1),
#  ('reduce', 1),
#  ('gradualmente', 1),
#  ('salud.', 1),
#  ('2020', 1),
#  ('2021,', 1),
#  ('salario', 1),
#  ('mínimo', 1),
#  ('bajará', 1),
#  ('2022', 1),
#  ('mesadas', 1),
#  ('mínimos,', 1),
#  ('pasará', 1),
#  ('10%.', 1),
#  ('“señor', 1),
#  ('juez,todos', 1),
#  ('testigos', 1),
#  ('contra', 1),
#  ('ciudadanos', 1),
#  ('acuartelados,', 1),
#  ('escúchese', 1),
#  ('bien:acuartelados', 1),
#  ('enemigos', 1),
#  ('políticos', 1),
#  ('álvaro', 1),
#  ('vélez,', 1),
#  ('quienes', 1),
#  ('obra', 1),
#  ('gracia', 1),
#  ('política', 1),
#  ('enardecida,', 1),
#  ('terminaron', 1),
#  ('siendo', 1),
#  ('mismo', 1),
#  ('tiempo', 1),
#  ('hermano”,', 1),
#  ('1/3defensa', 1),
#  ('uribe,tomado', 1),
#  ('semana:', 1),
#  ('jesús', 1),
#  ('albeiro', 1),
#  ('yepez”', 1),
#  ('demostró', 1),
#  ('estuvo', 1),
#  ('kilómetros', 1),
#  ('distante', 1),
#  ('donde', 1),
#  ('testigo', 1),
#  ('afirma', 1),
#  ('reunieron.', 1),
#  ('dos,', 1),
#  ('probado', 1),
#  ('sufre', 1),
#  ('esquizofrenia', 1),
#  ('tiene', 1),
#  ('distorsionada', 1),
#  ('realidad”', 1),
#  ('uribe;', 1),
#  ('“sus', 1),
#  ('abogados', 1),
#  ('(jesús', 1),
#  ('yepez)', 1),
#  ('presentaron', 1),
#  ('cuantioso', 1),
#  ('acervo', 1),
#  ('probatorio', 1),
#  ('mostrar', 1),
#  ('quieren', 1),
#  ('condenar', 1),
#  ('fantasmas,', 1),
#  ('impostores', 1),
#  ('esquizofrénicos.', 1),
#  ('uribe,', 1),
#  ('hora', 1),
#  ('juicio', 1),
#  ('caso', 1),
#  ("'los", 1),
#  ('doce', 1),
#  ("apóstoles'", 1),
#  ('barú,', 1),
#  ('cartagena', 1),
#  ('comunidades', 1),
#  ('cuidan', 1),
#  ('bioesfera', 1),
#  ('maya', 1),
#  ('guatemala', 1),
#  ('dolar', 1),
#  ('$3.320,82', 1),
#  ('$3.313,40', 1),
#  ('euro', 1),
#  ('$3.695,63', 1),
#  ('café', 1),
#  ('us$1,12', 1),
#  ('cent/lb;', 1),
#  ('precio', 1),
#  ('carga', 1),
#  ('$870.000', 1),
#  ('azucar', 1),
#  ('us$14.45', 1),
#  ('libra', 1),
#  ('petroleo', 1),
#  ('brent', 1),
#  ('us$64.61', 1),
#  ('us$58.81', 1),
#  ('metal', 1),
#  ('us$1.556,56', 1),
#  ('onza', 1),
#  ('plata', 1),
#  ('us$17.94', 1),
#  ('cobre', 1),
#  ('us$6.273', 1),
#  ('tonelada', 1),
#  ('tuve', 1),
#  ('dicha', 1),
#  ('conocer', 1),
#  ('compartir', 1),
#  ('gran', 1),
#  ('caimán', 1),
#  ('sánchez,', 1),
#  ('quiero', 1),
#  ('rendirle', 1),
#  ('homenaje', 1),
#  ('(q.e.p.d.),', 1),
#  ('familia', 1),
#  ('querida', 1),
#  ('amiga', 1),
#  ('clara', 1),
#  ('sánchez...', 1),
#  ('padre,', 1),
#  ('gloria', 1),
#  ('deporte', 1),
#  ('colombiano,', 1),
#  ('humano.', 1),
#  ('oriente', 1),
#  ('antioquia,', 1),
#  ('video', 1),
#  ('envía', 1),
#  ('turista', 1),
#  ('llamado', 1),
#  ('tantos', 1),
#  ('amigos:', 1),
#  ('difundir', 1),
#  ('necesidad', 1),
#  ('denunciar', 1),
#  ('asesinos', 1),
#  ('líderes', 1),
#  ('sociales,', 1),
#  ('recordar', 1),
#  ('gbno', 1),
#  ('ofrece', 1),
#  ('recompensas.', 1),
#  ('hace', 1),
#  ('mataron', 1),
#  ('ilusión', 1),
#  ('muchos', 1),
#  ('contar', 1),
#  ('unos', 1),
#  ('jóvenes', 1),
#  ('llenos', 1),
#  ('principios', 1),
#  ('noble', 1),
#  ('tarea', 1),
#  ('policías', 1),
#  ('plantea', 1),
#  ('ambiciosa', 1),
#  ('meta', 1),
#  ('inversión', 1),
#  ('extranjera', 1),
#  ('sectores', 1),
#  ('petroleros', 1),
#  ('valora', 1),
#  ('analitik', 1),
#  ('valiosas', 1),
#  ('razones', 1),
#  ('servir', 1),
#  ('colombia.', 1),
#  ('nuestros', 1),
#  ('héroes"', 1),
#  ('#díadelestudiantedepolicía', 1),
#  ('#leydehonores', 1),
#  ('video:', 1),
#  ('@infopresidencia', 1),
#  ('@fuerzasmilcol', 1),
#  ('@policiacolombia', 1),
#  ('@escueladcadetes', 1),
#  ('noticia', 1),
#  ('histórica', 1),
#  ('primera', 1),
#  ('años', 1),
#  ('participaremos', 1),
#  ('#seriedelcaribe', 1),
#  ('@sdcsanjuan2020', 1),
#  ('gracias', 1),
#  ('peloteros', 1),
#  ('abierto', 1),
#  ('puerta', 1),
#  ('internacional', 1),
#  ('entrada', 1),
#  ('este', 1),
#  ('certamen.', 1),
#  ('#unanuevahistoriadelbeisbol', 1),
#  ('olvidemos', 1),
#  ('venezuela', 1),
#  ('columna', 1),
#  ('plinio', 1),
#  ('apuleyo', 1),
#  ('mendoza', 1),
#  ('columnistas', 1),
#  ('opinión', 1),
#  ('boehler', 1),
#  ('destacó', 1),
#  ('esfuerzos', 1),
#  ('lucha', 1),
#  ('narcotráfico,', 1),
#  ('erradicación', 1),
#  ('cultivos', 1),
#  ('ilícitos', 1),
#  ('desarrollo', 1),
#  ('sostenible', 1),
#  ('ee.uu.', 1),
#  ('invertirá', 1),
#  ('us$5.000', 1),
#  ('narcotráfico', 1),
#  ('nuevo', 1),
#  ('siglo', 1),
#  ('bogotá', 1),
#  ('$3.313,26', 1),
#  ('$3.296,74', 1),
#  ('$3.700,81', 1),
#  ('$872.000', 1),
#  ('us$14.43', 1),
#  ('us$64.17', 1),
#  ('us$58.62', 1),
#  ('us$1,551,53', 1),
#  ('paladio', 1),
#  ('us$2.286,4', 1),
#  ('us$6.322', 1),
#  ('comunidad', 1),
#  ('informa:', 1),
#  ('escuchan', 1),
#  ('ráfagas', 1),
#  ('andagoya,', 1),
#  ('chocó”', 1),
#  ('heladas', 1),
#  ('valle', 1),
#  ('ubaté', 1),
#  ('están', 1),
#  ('afectando', 1),
#  ('ganadería', 1),
#  ('serían', 1),
#  ('mitigadas', 1),
#  ('silvopastoreo', 1),
#  ('@fedegan', 1),
#  ('@octaviovargasd', 1),
#  ('@desilvestrijg', 1),
#  ('@ojcubillosp', 1),
#  ('@ricardoansal', 1),
#  ('@alirestrepo', 1),
#  ('@cecollm', 1),
#  ('@vancliffdesign', 1),
#  ('@justiciaespaz35', 1),
#  ('@villanuevaguaj', 1),
#  ('@alfredohnc', 1),
#  ('@lacoutu', 1),
#  ('alcaldesa', 1),
#  ('claudia', 1),
#  ('lópez', 1),
#  ('tomó', 1),
#  ('conveniente', 1),
#  ('necesaria', 1),
#  ('decisión', 1),
#  ('autoridad,', 1),
#  ('protesta', 1),
#  ('puede', 1),
#  ('confundirse', 1),
#  ('vandalismo', 1),
#  ('gallinetas', 1),
#  ('blancas', 1),
#  ('buscan', 1),
#  ('árbol', 1),
#  ('pasar', 1),
#  ('noche,', 1),
#  ('puesta', 1),
#  ('transparencia,', 1),
#  ('celeridad', 1),
#  ('involucrar', 1),
#  ('ciudadanía', 1),
#  ('proyecto', 1),
#  ('importante', 1),
#  ('caldas', 1),
#  ('#ejecafetero,', 1),
#  ('objetivos', 1),
#  ('principales', 1),
#  ('comité', 1),
#  ('operativo', 1),
#  ('#aerocafé.este', 1),
#  ('grupo', 1),
#  ('encabezado', 1),
#  ('duque,que', 1),
#  ('está', 1),
#  ('comprometido', 1),
#  ('hacer', 1),
#  ('realidad', 1),
#  ('esta', 1),
#  ('julio', 1),
#  ('bahamón', 1),
#  ('parapeto.-', 1),
#  ('australia', 1),
#  ('dice:', 1),
#  ('lloren', 1),
#  ('habitantes', 1),
#  ('tierra,', 1),
#  ('mañana', 1),
#  ('llorar…', 1),
#  ('informa;', 1),
#  ('“otro', 1),
#  ('asesinato', 1),
#  ('quibdó,', 1),
#  ('urabeños,eln,', 1),
#  ('milicias,', 1),
#  ('disidentes', 1),
#  ('farc,', 1),
#  ('acabar', 1),
#  ('ciudad”', 1),
#  ('$3.296,73', 1),
#  ('$3.278,83', 1),
#  ('$3.680,84', 1),
#  ('us$1,14', 1),
#  ('$874.000', 1),
#  ('us$14.52', 1),
#  ('us$64.01', 1),
#  ('us$58.22', 1),
#  ('us$1.557,02', 1),
#  ('us$18.02', 1),
#  ('us$6.287', 1),
#  ('feliz', 1),
#  ('cumpleaños', 1),
#  ('#abejorral', 1),
#  ('tierra', 1),
#  ('señores', 1),
#  ('@julianmu25', 1),
#  ('@alvarouribevel', 1),
#  ('@paolaholguin', 1),
#  ('@mincomercioco', 1),
#  ('@jrestrp', 1),
#  ('@mincultura', 1),
#  ('@veronicaarango_', 1),
#  ('#atención', 1),
#  ('próximo', 1),
#  ('miércoles', 1),
#  ('enero', 1),
#  ('tendremos', 1),
#  ('sesión', 1),
#  ('#encuentrosconcolombia', 1),
#  ('houston', 1),
#  ('6pm.', 1),
#  ('será', 1),
#  ('oportunidad', 1),
#  ('presentar', 1),
#  ('resultados', 1),
#  ('dialogar', 1),
#  ('#colombianosenelexterior', 1),
#  ('trabajar', 1),
#  ('iniciativas', 1),
#  ('#colombianosenhouston.', 1),
#  ('¡los', 1),
#  ('espero!', 1),
#  ('bloquea', 1),
#  ('participación', 1),
#  ('foro', 1),
#  ('mundial', 1),
#  ('energías', 1),
#  ('primer', 1),
#  ('ministro', 1),
#  ('británico', 1),
#  ('abre', 1),
#  ('extensión', 1),
#  ('acuerdo', 1),
#  ('comercial', 1),
#  ('bruselas', 1),
#  ('martes', 1),
#  ('$3.278,86', 1),
#  ('$3.288,05', 1),
#  ('$3.659,94', 1),
#  ('$875.000', 1),
#  ('us$14.32', 1),
#  ('us$58.21', 1),
#  ('us$1.543,91onza', 1),
#  ('us$17.78', 1),
#  ('corregimiento', 1),
#  ('victoria,', 1),
#  ('municipio', 1),
#  ('#ipiales', 1),
#  ('atacado', 1),
#  ('violencia', 1),
#  ('pasado', 1),
#  ('grupos', 1),
#  ('guerrilleros,', 1),
#  ('recuperado', 1),
#  ('seguridad', 1),
#  ('democrática', 1),
#  ('presencia', 1),
#  ('constante', 1),
#  ('@col_ejercito', 1),
#  ('.#masproteccionalpueblo', 1),
#  ('país', 1),
#  ('sudamericano', 1),
#  ('crecer', 1),
#  ('veces', 1),
#  ('rápido', 1),
#  ('china', 1),
#  ('impacto', 1),
#  ('tendrá', 1),
#  ('sobre', 1),
#  ('venezuela)', 1),
#  ('tres', 1),
#  ('meses', 1),
#  ('consecutivos', 1),
#  ('llevaron', 1),
#  ('producción', 1),
#  ('cerrar', 1),
#  ('2019', 1),
#  ('récord', 1),
#  ('histórico', 1),
#  ('@fedecafeteros', 1),
#  ('@minagricultura', 1),
#  ('@andrsvalencia9', 1),
#  ('#buenasnoticias', 1),
#  ('repunte', 1),
#  ('cafetera', 1),
#  ('nacional.', 1),
#  ('registró', 1),
#  ('crecimiento', 1),
#  ('respecto', 1),
#  ('2018,', 1),
#  ('sumando', 1),
#  ('14,8', 1),
#  ('sacos.', 1),
#  ('volumen', 1),
#  ('registraba', 1),
#  ('desde', 1),
#  ('1992.', 1),
#  ('sector', 1),
#  ('apoya', 1),
#  ('permanentemente', 1),
#  ('abusiva', 1),
#  ('fraudulenta', 1),
#  ('confiscación', 1),
#  ('tierras', 1),
#  ('ramirez', 1),
#  ('gonzàlez', 1),
#  ('urrao,', 1),
#  ('antioquia', 1),
#  ('“agradecidos', 1),
#  ('gobernador', 1),
#  ('aníbal', 1),
#  ('gaviria', 1),
#  ('mandos', 1),
#  ('militares', 1),
#  ('policía', 1),
#  ('decisiones', 1),
#  ('recuperar', 1),
#  ('urrao”', 1),
#  ('bueno', 1),
#  ('mantengan', 1),
#  ('“vehículo', 1),
#  ('robado', 1),
#  ('papayal,', 1),
#  ('barrancas,', 1),
#  ('guajira,', 1),
#  ('dueño', 1),
#  ('pudo', 1),
#  ('pagar', 1),
#  ('extorsión', 1),
#  ('vehículo”', 1),
#  ('remesas', 1),
#  ('crecieron', 1),
#  ('directa', 1),
#  ('aumentó', 1),
#  ('19,24', 1),
#  ('2019;', 1),
#  ('salieron', 1),
#  ('us$1.887', 1),
#  ('portafolio', 1),
#  ('andrómeda:2014,plena', 1),
#  ('campaña', 1),
#  ('apoyo', 1),
#  ('oivánzuluaga,el', 1),
#  ('escándalo', 1),
#  ('agencia', 1),
#  ('ejército', 1),
#  ('hacía', 1),
#  ('interceptaciones', 1),
#  ('habana', 1),
#  ('informarme,', 1),
#  ('infamia', 1),
#  ('estimulada', 1),
#  ('santos.', 1),
#  ('algo', 1),
#  ('parecido', 1),
#  ('maltratar', 1),
#  ('centrodemocrático.', 1),
#  ('carecen', 1),
#  ('argumentos', 1),
#  ('ejecutará', 1),
#  ('inversiones', 1),
#  ('superiores', 1),
#  ('$7.5', 1),
#  ('billones', 1),
#  ('elevando', 1),
#  ('capacidad', 1),
#  ('energía', 1),
#  ('renovable', 1),
#  ('2.250', 1),
#  ('2022,', 1),
#  ('compromiso', 1),
#  ('gob.', 1),
#  ('pdte.', 1),
#  ('#irena10a', 1),
#  ('proximidades', 1),
#  ('nevado', 1),
#  ('ruiz', 1),
#  ('$3.288,11', 1),
#  ('$3.272,62', 1),
#  ('$3.642,21', 1),
#  ('us$1,16', 1),
#  ('$867.000', 1),
#  ('us$14.16', 1),
#  ('us$63.86', 1),
#  ('us$58.10', 1),
#  ('us$1.549,5', 1),
#  ('us$17.98', 1),
#  ('us$6.207', 1),
#  ('popayan', 1),
#  ('fundación', 1),
#  ('sebastián', 1),
#  ('belalcázar.', 1),
#  ('1537', 1),
#  ('(483', 1),
#  ('años).', 1),
#  ('carta', 1),
#  ('general', 1),
#  ('nicasio', 1),
#  ('martínez', 1),
#  ('informa', 1),
#  ('vereda', 1),
#  ('palambi,', 1),
#  ('chagüi,tumaco,', 1),
#  ('alias', 1),
#  ('giringo,', 1),
#  ('masacrando.', 1),
#  ('pirañas', 1),
#  ('chajal,', 1),
#  ('abajo', 1),
#  ('sube', 1),
#  ('fuerza', 1),
#  ('pública”', 1),
#  ('curiosidad', 1),
#  ('irresistible', 1),
#  ('juan', 1),
#  ('david', 1),
#  ('escobar', 1),
#  ('paisa', 1),
#  ('márquez', 1),
#  ('tienen', 1),
#  ('planes', 1),
#  ('entidades', 1),
#  ('estado', 1),
#  ('pública:', 1),
#  ('@bluradioco', 1),
#  ('prof', 1),
#  ('alfonso', 1),
#  ('monsalve,', 1),
#  ('periódico', 1),
#  ('debate', 1),
#  ('“fue', 1),
#  ('incapacidad', 1),
#  ('competir', 1),
#  ('desarrollos', 1),
#  ('científicos', 1),
#  ('tecnológicos', 1),
#  ('estados', 1),
#  ('unidos', 1),
#  ('japón,', 1),
#  ('corea', 1),
#  ('europa', 1),
#  ('occidental,', 1),
#  ('subsidiariamente),', 1),
#  ('llevó', 1),
#  ('colapso”', 1),
#  ('“china', 1),
#  ('tuvo', 1),
#  ('volverse', 1),
#  ('dictadura', 1),
#  ('capitalista', 1),
#  ('desarrollar', 1),
#  ('economía', 1),
#  ('cuba', 1),
#  ('parásitos', 1),
#  ('esto', 1),
#  ('campos', 1),
#  ('economía”', 1),
#  ('profesor', 1),
#  ('monsalve', 1),
#  ('debate:', 1),
#  ('ciencia,', 1),
#  ('tecnología', 1),
#  ('innovación', 1),
#  ('fracasaron', 1),
#  ('estruendosamente', 1),
#  ('antigua', 1),
#  ('unión', 1),
#  ('soviética”', 1),
#  ('otra', 1),
#  ('andrómeda?', 1),
#  ('ahora', 1),
#  ('calumnian', 1),
#  ('centro', 1),
#  ('democrático', 1),
#  ('cabeza', 1),
#  ('ilustre', 1),
#  ('integrante', 1),
#  ('confirmado', 1),
#  ('@revistasemana', 1),
#  ('ellos', 1),
#  ('"versión"', 1),
#  ('que,', 1),
#  ('consecuencia,', 1),
#  ('entregaron', 1),
#  ('@noticiasuno.', 1),
#  ('acá,', 1),
#  ('repito,', 1),
#  ('solo', 1),
#  ('información', 1),
#  ('alguna', 1),
#  ('sino', 1),
#  ('calumnia.', 1),
#  ('espero', 1),
#  ('rectificación', 1),
#  ('formal', 1),
#  ('otro', 1),
#  ('hacker?', 1),
#  ('pretenden?', 1),
#  ('hallan', 1),
#  ('micrófono', 1),
#  ('escondido', 1),
#  ('despacho', 1),
#  ('magistrado', 1),
#  ('investiga', 1),
#  ('heraldo', 1),
#  ('uber', 1),
#  ('compatriotas', 1),
#  ('taxistas', 1),
#  ('destacamos', 1),
#  ('acción', 1),
#  ('oportuna', 1),
#  ('conjunta', 1),
#  ('@fiscaliacol', 1),
#  ('alcalá,', 1),
#  ('cauca,', 1),
#  ('cual', 1),
#  ('logró', 1),
#  ('frustrar', 1),
#  ('atentado', 1),
#  ('rodrigo', 1),
#  ('londoño,', 1),
#  ('presidente', 1),
#  ('partido', 1),
#  ('farc.', 1),
#  ('nuestro', 1),
#  ('excombatientes', 1),
#  ('absoluto.', 1),
#  ('fácil', 1),
#  ('cuidar', 1),
#  ('democracia', 1),
#  ('recuperarla”', 1),
#  ('impostura:', 1),
#  ('farc', 1),
#  ('piden', 1),
#  ('gobernadores', 1),
#  ('alcaldes', 1),
#  ('satisfacer', 1),
#  ('exigencias.', 1),
#  ('por:', 1),
#  ('eduardo', 1),
#  ('mackenzie', 1),
#  ('barrios', 1),
#  ('conforman', 1),
#  ('orquesta', 1),
#  ('sinfónica', 1),
#  ('fundada', 1),
#  ('dentro', 1),
#  ('festival', 1),
#  ('música.', 1),
#  ('concierto', 1),
#  ('clausura', 1),
#  ('teatro', 1),
#  ('adolfo', 1),
#  ('mejia.', 1),
#  ('acierto', 1),
#  ('doña', 1),
#  ('julia', 1),
#  ('salvi”', 1),
#  ('reforma', 1),
#  ('justicia', 1),
#  ('juán', 1),
#  ('cubides', 1),
#  ('natura', 1),
#  ('linterna', 1),
#  ('azul', 1),
#  ('vallejo', 1),
#  ('regulado', 1),
#  ('tema', 1),
#  ('otros', 1),
#  ('países', 1),
#  ('mundo', 1),
#  ('estadio', 1),
#  ('beisbol', 1),
#  ('edgar', 1),
#  ('rentería.', 1),
#  ('luna', 1),
#  ('barranquilla', 1),
#  ('hogares', 1),
#  ('consumen', 1),
#  ('aportan', 1),
#  ('co2;', 1),
#  ('además,', 1),
#  ('humanos', 1),
#  ('disponible', 1),
#  ('0,05', 1),
#  ('agua', 1),
#  ('necesidades', 1),
#  ('mala', 1),
#  ('contaminando.', 1),
#  ('¿como', 1),
#  ('ayudar', 1),
#  ('planeta', 1),
#  ('sostenible?', 1),
#  ('…', 1),
#  ('titiribí,', 1),
#  ('ant,', 1),
#  ('alto', 1),
#  ('alpes', 1),
#  ('infamia:', 1),
#  ('“tienen', 1),
#  ('todo', 1),
#  ('listo', 1),
#  ('acusar', 1),
#  ('representante', 1),
#  ('cámara', 1),
#  ('miembros', 1),
#  ('recibían', 1),
#  ('reportes', 1),
#  ('supuestas', 1),
#  ('chuzadas', 1),
#  ('llegaba', 1),
#  ('expresidente', 1),
#  ('informacion', 1),
#  ('semana.,.”', 1),
#  ('@paterpau', 1),
#  ('increíble', 1),
#  ('echen', 1),
#  ('culpa', 1),
#  ('gobierno.....', 1),
#  ('desicion', 1),
#  ('misma', 1),
#  ('empresa', 1),
#  ('fallo', 1),
#  ('juez', 1),
#  ('república', 1),
#  ('superintendencia,', 1),
#  ('entes', 1),
#  ('autónomos', 1),
#  ('independientes.', 1),
#  ('yopal', 1),
#  ('tame', 1),
#  ('ratifican', 1),
#  ('fundamento,', 1),
#  ('sustento', 1),
#  ('paz.', 1),
#  ('evitemos', 1),
#  ('discurso', 1),
#  ('rabioso', 1),
#  ('siga', 1),
#  ('estigmatizando', 1),
#  ('fuerzas', 1),
#  ('armadas.', 1),
#  ('permitamos', 1),
#  ('patrocinadores', 1),
#  ('delincuencia', 1),
#  ('confundan', 1),
#  ('impunidad', 1),
#  ('uber:', 1),
#  ('debería', 1),
#  ('haber', 1),
#  ('problema', 1),
#  ('plataforma,', 1),
#  ('dueño,', 1),
#  ('percibe', 1),
#  ('ingresos', 1),
#  ('relaciona', 1),
#  ('personas', 1),
#  ('prestar', 1),
#  ('servicios,', 1),
#  ('contribuya', 1),
#  ('social,', 1),
#  ('cumpla', 1),
#  ('reglamentación', 1),
#  ('actividad', 1),
#  ('compita', 1),
#  ('equilibro', 1),
#  ('microempresas', 1),
#  ('pueden', 1),
#  ('inscribirse', 1),
#  ('programa', 1),
#  ('fábricas', 1),
#  ('productividad', 1),
#  ('@larepublica_co', 1),
#  ('istmina,', 1),
#  ('chocó,', 1),
#  ('banco', 1),
#  ('agrario', 1),
#  ('prepara', 1),
#  ('apoyar', 1),
#  ('productores', 1),
#  ('agropecuarios', 1),
#  ('afectados', 1),
#  ('#bancos', 1),
#  ('anuncio', 1),
#  ('hecho', 1),
#  ('entidad,', 1),
#  ('francisco', 1),
#  ('mejía,', 1),
#  ('quien', 1),
#  ('informó', 1),
#  ('entidad', 1),
#  ('contactar', 1),
#  ('clientes', 1),
#  ('zonas', 1),
#  ('afectadas.', 1),
#  ('@bancoagrario', 1),
#  ('@pachomejias', 1),
#  ('mintransporte', 1),
#  ('comunicado', 1),
#  ('pública', 1),
#  ('rechazamos', 1),
#  ('contundentemente', 1),
#  ('cobarde', 1),
#  ('ataque', 1),
#  ('perpetrado', 1),
#  ('base', 1),
#  ('@fuerzaaereacol', 1),
#  ('yopal,', 1),
#  ('casanare.', 1),
#  ('apoyamos', 1),
#  ('respaldamos', 1),
#  ('labor', 1),
#  ('territorio', 1),
#  ('nacional', 1),
#  ('colombianos.', 1),
#  ('estos', 1),
#  ('artículos', 1),
#  ('vigencia', 1),
#  ('pendientes', 1),
#  ('económico', 1),
#  ('hacerles', 1),
#  ('entender', 1),
#  ('reunido', 1),
#  ('suspenda', 1),
#  ('uber?', 1),
#  ('completamente', 1),
#  ('falso,', 1),
#  ('república,', 1),
#  ('único', 1),
#  ('buscar', 1),
#  ('solución', 1),
#  ('situación', 1),
#  ('todas', 1),
#  ('plataformas', 1),
#  ('discusión', 1),
#  ('ley,', 1),
#  ('conveniencia;', 1),
#  ('1.juez', 1),
#  ('ordena', 1),
#  ('suspensión', 1),
#  ('“porque', 1),
#  ('cobra', 1),
#  ('presta', 1),
#  ('servicio,', 1),
#  ('cumplir', 1),
#  ('requisitos', 1),
#  ('transporte”.', 1),
#  ('debe', 1),
#  ('social.', 1),
#  ('nivelar', 1),
#  ('cancha', 1),
#  ('como', 1),
#  ('toda', 1),
#  ('plataforma', 1),
#  ('social;', 1),
#  ('nivele', 1),
#  ('taxistas;', 1),
#  ('grave', 1),
#  ('sería', 1),
#  ('contrario.', 1),
#  ('120.000', 1),
#  ('usuarios', 1),
#  ('icetex', 1),
#  ('beneficiarán', 1),
#  ('plan', 1),
#  ('alivios', 1),
#  ('incentivos', 1),
#  ('anunciados', 1),
#  ('gobierno', 1),
#  ('#bogotá', 1),
#  ('madrugada', 1),
#  ('cobarde,', 1),
#  ('ejecutado', 1),
#  ('presión', 1),
#  ('organizaciones', 1),
#  ('criminales.', 1),
#  ('todos', 1),
#  ('indicios', 1),
#  ('señalan', 1),
#  ('responsable', 1),
#  ('eln.', 1),
#  ('respuesta', 1),
#  ('contundente.', 1),
#  ('pavos', 1),
#  ('reales', 1),
#  ('gallinetos', 1),
#  ('blancos', 1),
#  ('"uno', 1),
#  ('factores', 1),
#  ('afecta', 1),
#  ('educación', 1),
#  ('colombia,', 1),
#  ('duda', 1),
#  ('falta', 1),
#  ('continuidad', 1),
#  ('procesos', 1),
#  ('educativos..."', 1),
#  ("'están", 1),
#  ...]

# %%
create_word_cloud(sin_URLs,2)
